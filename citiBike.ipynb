# %%
import os
import os.path
import csv
from datetime import datetime
import pandas as pd
import numpy as np
import glob

# %%
citi201901_data = pd.read_csv("201901-citibike-tripdata.csv", error_bad_lines=False)
citi201902_data = pd.read_csv("201902-citibike-tripdata.csv", error_bad_lines=False)
citi201903_data = pd.read_csv("201903-citibike-tripdata.csv", error_bad_lines=False)
citi201904_data = pd.read_csv("201904-citibike-tripdata.csv", error_bad_lines=False)
citi201905_data = pd.read_csv("201905-citibike-tripdata.csv", error_bad_lines=False)
citi201906_data = pd.read_csv("201906-citibike-tripdata.csv", error_bad_lines=False)
citi201907_data = pd.read_csv("201907-citibike-tripdata.csv", error_bad_lines=False)
citi201908_data = pd.read_csv("201908-citibike-tripdata.csv", error_bad_lines=False)
citi201909_data = pd.read_csv("201909-citibike-tripdata.csv", error_bad_lines=False)
citi201910_data = pd.read_csv("201910-citibike-tripdata.csv", error_bad_lines=False)
citi201911_data = pd.read_csv("201911-citibike-tripdata.csv", error_bad_lines=False)
citi201912_data = pd.read_csv("201912-citibike-tripdata.csv", error_bad_lines=False)
citi202001_data = pd.read_csv("202001-citibike-tripdata.csv", error_bad_lines=False)
citi202002_data = pd.read_csv("202002-citibike-tripdata.csv", error_bad_lines=False)
citi202003_data = pd.read_csv("202003-citibike-tripdata.csv", error_bad_lines=False)
citi202004_data = pd.read_csv("202004-citibike-tripdata.csv", error_bad_lines=False)
citi202005_data = pd.read_csv("202005-citibike-tripdata.csv", error_bad_lines=False)

# %%
citi201901_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1           316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2           591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3          2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4           303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
#
#    start station id           start station name  start station latitude  \
# 0            3160.0  Central Park West & W 76 St               40.778968
# 1             519.0        Pershing Square North               40.751873
# 2            3171.0      Amsterdam Ave & W 82 St               40.785247
# 3             504.0              1 Ave & E 16 St               40.732219
# 4             229.0               Great Jones St               40.727434
#
#    start station longitude  end station id        end station name  \
# ...

# %% [markdown]
# citi202005_data.head()

# %%
citi202005_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           336  2020-05-01 00:01:06.3380  2020-05-01 00:06:42.9560
# 1           853  2020-05-01 00:01:08.1950  2020-05-01 00:15:21.2150
# 2            78  2020-05-01 00:01:08.5260  2020-05-01 00:02:27.0490
# 3          1185  2020-05-01 00:02:22.4380  2020-05-01 00:22:08.1220
# 4           272  2020-05-01 00:02:32.8280  2020-05-01 00:07:05.0880
#
#    start station id                  start station name  \
# 0              2017                     E 43 St & 2 Ave
# 1              3376                     E 65 St & 2 Ave
# 2               396          Lefferts Pl & Franklin Ave
# 3              3630  Frederick Douglass Blvd & W 115 St
# 4              3776          Central Ave & Starr Street
#
#    start station latitude  start station longitude  end station id  \
# 0               40.750224               -73.971214             465
# 1               40.764719               -73.962221             478
# ...

# %%
citi_frames = [citi201901_data, citi201902_data, citi201903_data, citi201904_data, citi201905_data, citi201906_data, citi201907_data, citi201908_data, citi201909_data, citi201910_data, citi201911_data, citi201912_data, citi202001_data, citi202002_data, citi202003_data, citi202004_data, citi202005_data]
citi_result = pd.concat(citi_frames)
citi_result
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...               ...                       ...                       ...
# 1487885           981  2020-05-31 23:59:19.0310  2020-06-01 00:15:40.5590
# 1487886           367  2020-05-31 23:59:36.2270  2020-06-01 00:05:43.6200
# 1487887          1798  2020-05-31 23:59:37.7250  2020-06-01 00:29:36.6800
# 1487888           718  2020-05-31 23:59:47.7090  2020-06-01 00:11:46.5210
# 1487889          1168  2020-05-31 23:59:48.0660  2020-06-01 00:19:16.4730
#
#          start station id           start station name  \
# ...

# %%
citi_result.to_csv('Citi_Total_data.csv')

# %%
citi_pre_covid = [citi201901_data, citi201902_data, citi201903_data, citi201904_data, citi201905_data, citi201906_data, citi201907_data, citi201908_data, citi201909_data, citi201910_data, citi201911_data, citi201912_data, citi202001_data]
citi_precovid_df = pd.concat(citi_pre_covid)
citi_precovid_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 320  2019-01-01 00:01:47.4010  2019-01-01 00:07:07.5810
# 1                 316  2019-01-01 00:04:43.7360  2019-01-01 00:10:00.6080
# 2                 591  2019-01-01 00:06:03.9970  2019-01-01 00:15:55.4380
# 3                2719  2019-01-01 00:07:03.5450  2019-01-01 00:52:22.6500
# 4                 303  2019-01-01 00:07:35.9450  2019-01-01 00:12:39.5020
# ...               ...                       ...                       ...
# 1240591          1587  2020-01-31 23:59:26.8820  2020-02-01 00:25:54.4890
# 1240592           222  2020-01-31 23:59:32.6410  2020-02-01 00:03:15.4720
# 1240593           163  2020-01-31 23:59:39.1780  2020-02-01 00:02:23.0400
# 1240594           327  2020-01-31 23:59:49.2310  2020-02-01 00:05:16.3790
# 1240595           484  2020-01-31 23:59:57.0360  2020-02-01 00:08:01.1820
#
#          start station id           start station name  \
# ...

# %%
citi_precovid_df.to_csv('Citi_precovid.csv')

# %%
citi_covid = [citi202002_data, citi202003_data, citi202004_data, citi202005_data]
citi_covid_df = pd.concat(citi_covid)
citi_covid_df
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                1404  2020-02-01 00:00:05.9460  2020-02-01 00:23:30.7240
# 1                1301  2020-02-01 00:00:06.2230  2020-02-01 00:21:48.0580
# 2                 474  2020-02-01 00:00:15.7210  2020-02-01 00:08:10.3440
# 3                 487  2020-02-01 00:00:21.0520  2020-02-01 00:08:28.7520
# 4                 619  2020-02-01 00:00:27.4000  2020-02-01 00:10:47.0640
# ...               ...                       ...                       ...
# 1487885           981  2020-05-31 23:59:19.0310  2020-06-01 00:15:40.5590
# 1487886           367  2020-05-31 23:59:36.2270  2020-06-01 00:05:43.6200
# 1487887          1798  2020-05-31 23:59:37.7250  2020-06-01 00:29:36.6800
# 1487888           718  2020-05-31 23:59:47.7090  2020-06-01 00:11:46.5210
# 1487889          1168  2020-05-31 23:59:48.0660  2020-06-01 00:19:16.4730
#
#          start station id         start station name  start station latitude  \
# ...

# %%
citi_covid_df.to_csv('Citi_covid.csv')

# %%
citi_feb_may2019 = [citi201902_data, citi201903_data, citi201904_data, citi201905_data]
citi_spring2019 = pd.concat(citi_feb_may2019)
citi_spring2019
# Out:
#          tripduration                 starttime                  stoptime  \
# 0                 219  2019-02-01 00:00:06.2570  2019-02-01 00:03:46.1090
# 1                 143  2019-02-01 00:00:28.0320  2019-02-01 00:02:51.7460
# 2                 296  2019-02-01 00:01:13.9870  2019-02-01 00:06:10.7340
# 3                 478  2019-02-01 00:01:14.1520  2019-02-01 00:09:12.7870
# 4                 225  2019-02-01 00:01:49.3410  2019-02-01 00:05:34.4980
# ...               ...                       ...                       ...
# 1924558           304  2019-05-31 23:59:45.5760  2019-06-01 00:04:50.4620
# 1924559           324  2019-05-31 23:59:46.4650  2019-06-01 00:05:11.1630
# 1924560          1926  2019-05-31 23:59:51.5060  2019-06-01 00:31:58.3920
# 1924561          2047  2019-05-31 23:59:52.4170  2019-06-01 00:34:00.1970
# 1924562           964  2019-05-31 23:59:55.5500  2019-06-01 00:15:59.8680
#
#          start station id        start station name  start station latitude  \
# ...

# %%
citi_spring2019.to_csv('Citi_spring2019.csv')
